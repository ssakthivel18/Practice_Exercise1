# %% [markdown]
# # Experiment 1 Analysis

# %%
#Import all necessary libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
#Load data from Experiment 1
data1 = pd.read_csv('reactiontime.csv')
print(data1)
# Out:
#     trial_number  reaction_time  accuracy
# 0              1            420        90
# 1              2            424       100
# 2              3            355       100
# 3              4            341        90
# 4              5            380       100
# 5              6            382       100
# 6              7            384        90
# 7              8            358        90
# 8              9            365       100
# 9             10            369       100
# 10            11            379        90
# 11            12            345       100
# 12            13            340       100
# 13            14            308        90
# 14            15            358       100
# 15            16            336        90
# 16            17            332        90
# 17            18            330       100
# 18            19            330       100
# 19            20            312        90

# %%
# Scatterplot of data
plt.figure(figsize=(10, 5))
plt.plot(data1['trial_number'], data1['reaction_time'], 'o')

#obtain m (slope) and b(intercept) of linear regression line
m, b = np.polyfit(data1['trial_number'], data1['reaction_time'], 1)

#add linear regression line to scatterplot 
plt.plot(data1['trial_number'], m*(data1['trial_number'])+b)

plt.xlabel('Trial Number')
plt.ylabel('Reaction Time (ms)')
plt.title('Reaction Time Experiment 1')
plt.legend(['Regression Line: y = {:.2f}x + {:.2f}'.format(m, b)])
plt.show()

# %%
#plot showing accuracy through the experiment
plt.figure(figsize=(10, 5))
plt.plot(data1['trial_number'], data1['accuracy'])
plt.xlabel('Trial Number')
plt.ylabel('Accuracy')
plt.title('Reaction Time Experiment 1')
plt.show()

# %%
#Summary data from the experiment
print('The average reaction time for this experiment was', data1['reaction_time'].mean(), 'ms.')
print('The average accuracy for this experiment was', data1['accuracy'].mean(), "%.")
# Out:
# The average reaction time for this experiment was 357.4 ms.
# The average accuracy for this experiment was 95.5 %.

# %% [markdown]
# # Experiment 2 Analysis

# %%
#Load data from Experiment 1
data2 = pd.read_csv('reactiontime2.csv')
print(data2)
# Out:
#     trial_number  reaction_time  accuracy
# 0              1            441        87
# 1              2            406        93
# 2              3            466        87
# 3              4            450        93
# 4              5            448       100
# 5              6            449       100
# 6              7            454        93
# 7              8            461       100
# 8              9            457        93
# 9             10            451        93
# 10            11            440       100
# 11            12            438        93
# 12            13            430        93
# 13            14            441       100
# 14            15            402        93
# 15            16            427        87
# 16            17            439       100
# 17            18            409        93
# 18            19            405        93
# 19            20            428       100

# %%
# Scatterplot of data
plt.figure(figsize=(10, 5))
plt.plot(data2['trial_number'], data2['reaction_time'], 'o')

#obtain m (slope) and b(intercept) of linear regression line
m, b = np.polyfit(data2['trial_number'], data2['reaction_time'], 1)

#add linear regression line to scatterplot 
plt.plot(data2['trial_number'], m*(data2['trial_number'])+b)

plt.xlabel('Trial Number')
plt.ylabel('Reaction Time (ms)')
plt.title('Reaction Time Experiment 2')
plt.legend(['Regression Line: y = {:.2f}x + {:.2f}'.format(m, b)])
plt.show()

# %%
#plot showing accuracy through the experiment
plt.figure(figsize=(10, 5))
plt.plot(data2['trial_number'], data2['accuracy'])
plt.xlabel('Trial Number')
plt.ylabel('Accuracy')
plt.title('Reaction Time Experiment 2')
plt.show()

# %%
#Summary data from the experiment
print('The average reaction time for this experiment was', data2['reaction_time'].mean(), 'ms.')
print('The average accuracy for this experiment was', data2['accuracy'].mean(), "%.")
# Out:
# The average reaction time for this experiment was 437.1 ms.
# The average accuracy for this experiment was 94.55 %.
